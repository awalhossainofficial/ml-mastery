# %%
msg = """ Hello there, 
How are you? i've been waiting for you."""

frst_msg = msg[1::3]
check = msg.find("you")
print(check)
# Out:
# 23

# %%
import os
if os.path.exists("demo.txt"):
    print("yes")
else:
    print("no")
