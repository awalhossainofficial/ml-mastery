# %%
lst =[x for x in range(500)]
def load_dataset(chunk,lst):
    for i in range(len(lst)):
        yield lst[i:chunk:i+chunk]

x = load_dataset(5,lst)
# print(next(x))
# print(next(x))
# print(next(x))
for i in lst:
    print(i)
print(lst)
# Out:
#   Cell In[14], line 1
#     lst =[x for x in range(500:)]
#                               ^
# SyntaxError: invalid syntax
