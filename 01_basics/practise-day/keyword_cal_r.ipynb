# %%
text = input("Please input the sentenc: ").strip().split()

if not text:
    print("No words provided")
else:
    long_word = text[0]
    for i in text:
        if len(long_word) < len(i):
            long_word = i
# Out:
# doing
