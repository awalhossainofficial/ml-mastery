# %%
n = int(input())
target = int(input())
total = 0

for i in range(n):
    loss = float(input())
    total += loss

avg = total / n

if avg >= target:
    print("FAIL")
else:
    print("PASS")
# Out:
#   Cell In[5], line 15
#     print(total)
#     ^
# IndentationError: expected an indented block after 'else' statement on line 13
