# %%
inpt = input().split() 
arr = input().split()
a = set(map(int,input().split()))
b = set(map(int,input().split()))
total = 0

for i in arr:
    if int(i) in a:
        total +=1
    elif int(i) in b:
        total -=1

print(total)
# Out:
# <class 'set'> <class 'set'> print {1, 5} {5, 7}
# 2 total
