# %%
inpt = input()
# inpt = inpt.split() 

dic = {}
for i in inpt:
    dic[i] = dic.get(i,0)+1

for char in sorted(dic.keys()):
    print(f"{char} : {dic[char]}")
# Out:
# e : 1
# f : 2
# g : 1
# r : 1
