# %%
text = input()

if "happy" in text or "joy" in text or "smile" in text:
    print("Happy Mood")
elif "sad" in text or "cry" in text or "angry" in text:
    print("Sad Mood")
else:
    print("Neutral Mood")
# Out:
# Sad Mood
