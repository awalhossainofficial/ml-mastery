# %%
import pandas as pd
df = pd.DataFrame({
    "name": ["Alice", "Bob", None, "Eve"],
    "email": ["a@x.com", None, "c@z.com", "e@z.com"],
    "age": [25, 30, 21, None]
})
print(df)
df.isnull().values.any(axis=0)
df = df.fillna({"age":df['age'].mean(), "email":"df@mail.com" } )
df
# df.dropna()
# Output: True
# Out:
#     name    email   age
# 0  Alice  a@x.com  25.0
# 1    Bob     None  30.0
# 2   None  c@z.com  21.0
# 3    Eve  e@z.com   NaN
#     name        email        age
# 0  Alice      a@x.com  25.000000
# 1    Bob  df@mail.com  30.000000
# 2   None      c@z.com  21.000000
# 3    Eve      e@z.com  25.333333

# %%
def dropMissingData(students: pd.DataFrame) -> pd.DataFrame:
    df = students.dropna(subset=["name"])
    print(df)
    return df
