# %%
nums = list(range(5))
print(nums,"hello")

def find_index_number(index):
    try:
        return nums[index]
    except IndexError:
        print("Invalid index!")
    except ValueError:
        print("Please enter a valid integer index")


find_index_number(33)
# Out:
# [0, 1, 2, 3, 4] hello
# Invalid index!
