# %%
students = [("Rafi", 89), ("Sumi", 95), ("Hasan", 90), ("Nila", 75), ("Anik", 98)]
# students = dict(students)
# for x,y in students.items():
#     log

srt = sorted(students, key=lambda item: item[1], reverse=True )

print(students,"check",srt)
print (f"Top 3 students \n {srt[0][0]} - {srt[0][1]} \n {srt[1]} \n {srt[2]}")
print("Top 3 students:")
# for name, mark in srt[:3]:
#     print(f"{name} - {mark}")
# Out:
# [('Rafi', 89), ('Sumi', 95), ('Hasan', 90), ('Nila', 75), ('Anik', 98)] check [('Anik', 98), ('Sumi', 95), ('Hasan', 90), ('Rafi', 89), ('Nila', 75)]
# Top 3 students
#  Anik - 98
#  ('Sumi', 95)
#  ('Hasan', 90)
# Top 3 students:
