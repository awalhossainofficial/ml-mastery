# %%
a_friends = {"Rahim", "Karim", "Sakib", "Jamal"}
b_friends = {"Sakib", "Jamal", "Rafiq", "Nadim"}

mutual = a_friends & b_friends
unique_a = a_friends.difference(b_friends)
unique_b = b_friends.difference(a_friends)
total_unique = a_friends | b_friends
print(mutual, "unique", unique_b, "total unique", len(total_unique))
# Out:
# {'Sakib', 'Jamal'} unique {'Nadim', 'Rafiq'} total unique 6
