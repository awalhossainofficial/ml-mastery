# %%
words = ["sun", "planet", "moon", "star", "universe"]

newW = list(filter(lambda x: len(x)>4, words))
print(newW)
# Out:
# ['planet', 'universe']

# %%
nums = [1, 2, 3, 4, 5, 6]

square_nums = list([filter(lambda x: x % 2 == 0, nums)])
print(square_nums)
