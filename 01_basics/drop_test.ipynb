# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.arange(12).reshape(3, 4),columns=['A', 'B', 'C', 'D'])
dat = np.arange(10).reshape(3,4)                  
print(dat)
# df.drop([0,1],axis=0)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 5
#       2 import numpy as np
#       4 df = pd.DataFrame(np.arange(12).reshape(3, 4),columns=['A', 'B', 'C', 'D'])
# ----> 5 dat = np.arange(10).reshape(3,4)
#       6 print(dat)
#       7 # df.drop([0,1],axis=0)
#
# ValueError: cannot reshape array of size 10 into shape (3,4)
