# %%
import pandas as pd

# Sample dataset
data = {
    'Region': ['North', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West'],
    'Product': ['A', 'A', 'C', 'B', 'B', 'A', 'B', 'B', 'A'],
    'Month': ['Jan', 'Jan', 'Apr', 'Jan', 'Jan', 'Feb', 'Feb', 'Feb', 'Feb'],
    'Sales': [120, 80, 90, 800, 100, 140, 110, 95, 105],
    'Quantity': [30, 25, 30, 20, 22, 35, 28, 24, 27]
}

df = pd.DataFrame(data)
df.pivot_table(index='Month', columns='Product', values=['Sales', 'Quantity'], fill_value=0)
# Out:
#         Quantity              Sales
# Product        A     B     C      A      B     C
# Month
# Apr          0.0   0.0  30.0    0.0    0.0  90.0
# Feb         31.0  26.0   0.0  122.5  102.5   0.0
# Jan         27.5  21.0   0.0  100.0  450.0   0.0
