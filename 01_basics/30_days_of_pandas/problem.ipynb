# %%
import pandas as pd

dic = {
    'Product': ['Pen', 'Book', 'Eraser', 'Pencil'],
    'Price': [10, 50, 5, 7],
    'Quantity': [100, 60, 200, 150]
}
col = pd.DataFrame(dic)

print(col.columns)
print(col.index)
# Out:
# Index(['Product', 'Price', 'Quantity'], dtype='object')
# RangeIndex(start=0, stop=4, step=1)

# %%
df = pd.read_csv("student.csv")
df["FullName"].unique()
print(df["FullName"].nunique())
# Out:
# 20
